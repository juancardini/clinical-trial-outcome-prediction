# %% [markdown]
# ###Objective: Read a CSV with Studies Graph Metrics

# %%
import pandas as pd

path = '/Volumes/workspace/default/tesis_volume/grafometricas.csv'

df_spark = (spark.read

    .format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load(path)
)
df=df_spark.withColumnRenamed("s.community_louvain","community_louvain")
df_grafo = df.createOrReplaceTempView("df_grafo")
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>study_id</th><th>degree_total</th><th>degree_norm</th><th>pagerank_norm</th><th>betweenness_norm</th><th>closeness_norm</th><th>community_louvain</th><th>n_conditions</th><th>n_countries</th><th>n_interventions</th><th>n_facilities</th><th>n_sponsor_lead</th><th>n_sponsor_collaborator</th><th>n_sponsors_total</th><th>emb_0</th><th>emb_1</th><th>emb_2</th><th>emb_3</th><th>emb_4</th><th>emb_5</th><th>emb_6</th><th>emb_7</th><th>emb_8</th><th>emb_9</th><th>emb_10</th><th>emb_11</th><th>emb_12</th><th>emb_13</th><th>emb_14</th><th>emb_15</th><th>emb_16</th><th>emb_17</th><th>emb_18</th><th>emb_19</th><th>emb_20</th><th>emb_21</th><th>emb_22</th><th>emb_23</th><th>emb_24</th><th>emb_25</th><th>emb_26</th><th>emb_27</th><th>emb_28</th><th>emb_29</th><th>emb_30</th><th>emb_31</th><th>emb_32</th><th>emb_33</th><th>emb_34</th><th>emb_35</th><th>emb_36</th><th>emb_37</th><th>emb_38</th><th>emb_39</th><th>emb_40</th><th>emb_41</th><th>emb_42</th><th>emb_43</th><th>emb_44</th><th>emb_45</th><th>emb_46</th><th>emb_47</th><th>emb_48</th><th>emb_49</th><th>emb_50</th><th>emb_51</th><th>emb_52</th><th>emb_53</th><th>emb_54</th><th>emb_55</th><th>emb_56</th><th>emb_57</th><th>emb_58</th><th>emb_59</th><th>emb_60</th><th>emb_61</th><th>emb_62</th><th>emb_63</th></tr></thead><tbody><tr><td>NCT06759701</td><td>7.0</td><td>0.005447470817120622</td><td>0.003471731316723185</td><td>7.398310879902534E-4</td><td>0.8652291254449072</td><td>89243</td><td>2</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0</td><td>1</td><td>-0.0023504695665220445</td><td>-0.003533334623017649</td><td>-0.003403003356396581</td><td>-0.003068849624614729</td><td>-0.002420077142607583</td><td>-0.02581802405493032</td><td>-0.0057123461394417985</td><td>-0.00483687097899107</td><td>-7.779481502778838E-4</td><td>-0.0036415558133117585</td><td>-0.004039613632508469</td><td>0.33697314724914873</td><td>0.4308650375012549</td><td>-0.0213314863999711</td><td>-0.007289938076589388</td><td>-0.01011834564300062</td><td>-0.004477083095167344</td><td>-0.0151276691149221</td><td>-0.023943036850462195</td><td>-0.006901430123376209</td><td>-0.007147744917067215</td><td>-0.007863254272773079</td><td>-0.010270998693807773</td><td>-0.004515376414108844</td><td>-0.005431116941090974</td><td>-0.004006303300620821</td><td>-4.5932924931729307E-4</td><td>-0.01692962107229009</td><td>0.07458608843466781</td><td>0.29055882607220596</td><td>-0.020321841685962256</td><td>-0.0036549969157180506</td><td>-0.006028524198006736</td><td>-0.01085118277278847</td><td>-0.0106573910786227</td><td>0.09803097753450074</td><td>-0.003496472191626371</td><td>-0.006832317274675541</td><td>-0.0063620345805854225</td><td>-0.015304579877493481</td><td>-0.014834129581525548</td><td>-0.016099508389207175</td><td>-0.00195339800661294</td><td>-0.019360568488024785</td><td>-8.986511126492734E-4</td><td>-0.007923456087194468</td><td>-0.012402074096887193</td><td>0.7682167926303357</td><td>-0.008366398588151495</td><td>-0.005249510718507318</td><td>-2.0825773848658606E-5</td><td>-0.013146091985527334</td><td>-0.006364268536115357</td><td>-0.004156055601121274</td><td>-0.0022606027943407694</td><td>-0.012674835309769717</td><td>-0.00218650914756233</td><td>-0.029117538428985477</td><td>0.06659132699684044</td><td>-0.003986238140925994</td><td>-0.010807593649252866</td><td>-5.801040291520199E-4</td><td>-0.00789158563664495</td><td>-0.011021535914026138</td></tr><tr><td>NCT02011633</td><td>8.0</td><td>0.0062256809338521405</td><td>0.004584509930788426</td><td>0.001022168779844151</td><td>0.6852600116815022</td><td>41719</td><td>1</td><td>1</td><td>3</td><td>1</td><td>1</td><td>0</td><td>1</td><td>-0.015460517668399476</td><td>-0.005915186357777421</td><td>-0.015146251787837748</td><td>-0.022898711245591792</td><td>-0.007912960120211464</td><td>-0.08156508207062033</td><td>-0.03685833280565535</td><td>-0.026815103 ...

# %% [markdown]
# Studies Data

# %%
#  Load Gold Tables

df_studies_spark        = spark.table("gold.nodes_studies")
df_interventions_spark  = spark.table("gold.nodes_interventions")
df_rels_interv_spark    = spark.table("gold.rels_study_intervention")
df_sponsors_spark       = spark.table("gold.nodes_sponsors")
df_rels_spon_spark      = spark.table("gold.rels_study_sponsor")
df_facilities_spark     = spark.table("gold.nodes_facilities")
df_rels_fac_spark       = spark.table("gold.rels_study_facility")
df_countries_spark      = spark.table("gold.nodes_countries")
df_rels_ctry_spark      = spark.table("gold.rels_study_country")
df_conditions_spark     = spark.table("gold.nodes_conditions")
df_rels_cond_spark      = spark.table("gold.rels_study_condition")


# Create Views

df_studies_spark.createOrReplaceTempView("vw_nodes_studies")
df_interventions_spark.createOrReplaceTempView("vw_nodes_interventions")
df_rels_interv_spark.createOrReplaceTempView("vw_rels_study_intervention")
df_sponsors_spark.createOrReplaceTempView("vw_nodes_sponsors")
df_rels_spon_spark.createOrReplaceTempView("vw_rels_study_sponsor")
df_facilities_spark.createOrReplaceTempView("vw_nodes_facilities")
df_rels_fac_spark.createOrReplaceTempView("vw_rels_study_facility")
df_countries_spark.createOrReplaceTempView("vw_nodes_countries")
df_rels_ctry_spark.createOrReplaceTempView("vw_rels_study_country")
df_conditions_spark.createOrReplaceTempView("vw_nodes_conditions")
df_rels_cond_spark.createOrReplaceTempView("vw_rels_study_condition")

# %%
# %sql
create or replace temp view n_conditions as 
select count(distinct condition_name) as n_conditions,study_id 
from gold.rels_study_condition 
group by study_id;
select * from n_conditions limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>n_conditions</th><th>study_id</th></tr></thead><tbody><tr><td>4</td><td>NCT01087086</td></tr><tr><td>3</td><td>NCT04078308</td></tr><tr><td>1</td><td>NCT06654960</td></tr><tr><td>2</td><td>NCT00993096</td></tr><tr><td>4</td><td>NCT04583813</td></tr><tr><td>4</td><td>NCT06059404</td></tr><tr><td>1</td><td>NCT02542631</td></tr><tr><td>4</td><td>NCT06092515</td></tr><tr><td>6</td><td>NCT06366399</td></tr><tr><td>1</td><td>NCT03062475</td></tr></tbody></table></div>

# %%
# %sql
create or replace temp view n_countries as 
select study_id,count(distinct country_name) as n_countries 
from gold.rels_study_country
group by study_id;
select * from n_countries
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
01722266</td><td>1</td></tr><tr><td>NCT01512979</td><td>12</td></tr><tr><td>NCT03250533</td><td>1</td></tr><tr><td>NCT02049359</td><td>1</td></tr><tr><td>NCT00817505</td><td>1</td></tr><tr><td>NCT00771901</td><td>1</td></tr><tr><td>NCT04316052</td><td>1</td></tr><tr><td>NCT01572649</td><td>4</td></tr><tr><td>NCT05992545</td><td>1</td></tr><tr><td>NCT03215173</td><td>1</td></tr><tr><td>NCT01135771</td><td>1</td></tr><tr><td>NCT01204580</td><td>1</td></tr><tr><td>NCT04071626</td><td>1</td></tr><tr><td>NCT06704035</td><td>1</td></tr><tr><td>NCT01814137</td><td>5</td></tr><tr><td>NCT01620489</td><td>6</td></tr><tr><td>NCT03713684</td><td>3</td></tr><tr><td>NCT00639964</td><td>1</td></tr><tr><td>NCT07021690</td><td>1</td></tr><tr><td>NCT00553488</td><td>1</td></tr><tr><td>NCT00609895</td><td>1</td></tr><tr><td>NCT04419337</td><td>1</td></tr><tr><td>NCT02266823</td><td>1</td></tr><tr><td>NCT06473831</td><td>1</td></tr><tr><td>NCT01774474</td><td>7</td></tr><tr><td>NCT02227862</td><td>11</td></tr><tr><td>NCT00597233</td><td>1</td></tr><tr><td>NCT05881200</td><td>1</td></tr><tr><td>NCT03066830</td><td>10</td></tr><tr><td>NCT00614055</td><td>5</td></tr><tr><td>NCT02631928</td><t ...

# %%
# %sql
create or replace temp view n_interventions as 
select study_id,count (distinct intervention_name) as n_interventions 
from gold.rels_study_intervention
group by study_id;
select * from n_interventions limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>study_id</th><th>n_interventions</th></tr></thead><tbody><tr><td>NCT00311077</td><td>1</td></tr><tr><td>NCT02156037</td><td>2</td></tr><tr><td>NCT02422446</td><td>1</td></tr><tr><td>NCT04092959</td><td>3</td></tr><tr><td>NCT02099110</td><td>9</td></tr><tr><td>NCT02246400</td><td>1</td></tr><tr><td>NCT00950040</td><td>2</td></tr><tr><td>NCT02954692</td><td>9</td></tr><tr><td>NCT00839527</td><td>6</td></tr><tr><td>NCT02011633</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
create or replace temp view n_sponsors as SELECT 
  r.study_id,
  COUNT(DISTINCT CASE 
    WHEN UPPER(s.lead_or_collaborator) = 'LEAD' 
      THEN s.sponsor_name 
  END) AS n_sponsor_lead,
  COUNT(DISTINCT CASE 
    WHEN UPPER(s.lead_or_collaborator) = 'COLLABORATOR' 
      THEN s.sponsor_name 
  END) AS n_sponsor_collaborator
FROM gold.rels_study_sponsor r
JOIN gold.nodes_sponsors s 
  ON UPPER(TRIM(s.sponsor_name)) = UPPER(TRIM(r.sponsor_name))
GROUP BY r.study_id;
select * from n_sponsors limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>study_id</th><th>n_sponsor_lead</th><th>n_sponsor_collaborator</th></tr></thead><tbody><tr><td>NCT00461058</td><td>1</td><td>1</td></tr><tr><td>NCT00678990</td><td>1</td><td>0</td></tr><tr><td>NCT01155518</td><td>1</td><td>2</td></tr><tr><td>NCT05023993</td><td>1</td><td>1</td></tr><tr><td>NCT00601250</td><td>1</td><td>1</td></tr><tr><td>NCT01286350</td><td>7</td><td>7</td></tr><tr><td>NCT00140543</td><td>3</td><td>5</td></tr><tr><td>NCT00879697</td><td>1</td><td>2</td></tr><tr><td>NCT01108276</td><td>1</td><td>2</td></tr><tr><td>NCT02482584</td><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql

create or replace temp view n_facilities as 
  SELECT
    r.study_id,
    count(distinct f.facility_id) as n_facilities
    
  FROM gold.rels_study_facility r
  JOIN gold.nodes_facilities f
    ON r.facility_id = f.facility_id
    group by r.study_id
    ;
    select * from n_facilities limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>study_id</th><th>n_facilities</th></tr></thead><tbody><tr><td>NCT04383639</td><td>1</td></tr><tr><td>NCT02967211</td><td>118</td></tr><tr><td>NCT00330473</td><td>60</td></tr><tr><td>NCT01435616</td><td>167</td></tr><tr><td>NCT00619697</td><td>54</td></tr><tr><td>NCT01732705</td><td>1</td></tr><tr><td>NCT01126580</td><td>91</td></tr><tr><td>NCT00141492</td><td>70</td></tr><tr><td>NCT04628481</td><td>57</td></tr><tr><td>NCT00549757</td><td>776</td></tr></tbody></table></div>

# %%
# %sql


CREATE OR REPLACE TEMP VIEW design_features AS
SELECT
  r.study_id,

  d.allocation,
  d.primary_purpose,
  d.intervention_model,
  d.masking,
  CASE 
    WHEN d.masking IS NULL OR UPPER(d.masking) = 'NONE' THEN 0 
    ELSE 1 
  END AS is_blinded,

  -- Masked Roles
  COALESCE(CAST(d.subject_masked      AS INT), 0) AS subject_masked_int,
  COALESCE(CAST(d.caregiver_masked    AS INT), 0) AS caregiver_masked_int,
  COALESCE(CAST(d.investigator_masked AS INT), 0) AS investigator_masked_int,

  ( COALESCE(CAST(d.subject_masked      AS INT), 0)
  + COALESCE(CAST(d.caregiver_masked    AS INT), 0)
  + COALESCE(CAST(d.investigator_masked AS INT), 0)
  ) AS n_roles_masked

FROM gold.rels_study_design r
JOIN gold.nodes_designs d
  ON r.design_id = d.design_id;
select * from design_features limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>study_id</th><th>allocation</th><th>primary_purpose</th><th>intervention_model</th><th>masking</th><th>is_blinded</th><th>subject_masked_int</th><th>caregiver_masked_int</th><th>investigator_masked_int</th><th>n_roles_masked</th></tr></thead><tbody><tr><td>NCT03053518</td><td>NON_RANDOMIZED</td><td>TREATMENT</td><td>PARALLEL</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT02773875</td><td>RANDOMIZED</td><td>TREATMENT</td><td>CROSSOVER</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT03684642</td><td>RANDOMIZED</td><td>TREATMENT</td><td>PARALLEL</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT02862860</td><td>NON_RANDOMIZED</td><td>null</td><td>PARALLEL</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT05670379</td><td>RANDOMIZED</td><td>TREATMENT</td><td>PARALLEL</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT07157384</td><td>RANDOMIZED</td><td>TREATMENT</td><td>PARALLEL</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT01911104</td><td>NON_RANDOMIZED</td><td>TREATMENT</td><td>SINGLE_GROUP</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT04531631</td><td>RANDOMIZED</td><td>OTHER</td><td>CROSSOVER</td><td>TRIPLE</td><td>1</td><td>1</td><td>1</td><td>1</td><td>3</td></tr><tr><td>NCT00562952</td><td>RANDOMIZED</td><td>PREVENTION</td><td>PARALLEL</td><td>NONE</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>NCT00381342</td><td>RANDOMIZED</td><td>TREATMENT</td><td>PARALLEL</td><td>DOUBLE</td><td>1</td><td>1</td><td>0</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TEMP VIEW dataset_ml AS
SELECT
    g.study_id,
s.brief_title,
    -- Clinical Variables
    
    s.approved,

    -- Graph Metrics
    g.degree_total,
    g.degree_norm,
    g.pagerank_norm,
    g.betweenness_norm,
    g.closeness_norm,
    g.community_louvain,

  -- Quantitative Variables
    nc.n_conditions,
    nctr.n_countries,
    ni.n_interventions,
    nf.n_facilities,
    --EMBEDDINGS
    g.emb_0,
    g.emb_1,
    g.emb_2,
    g.emb_3,
    g.emb_4,
    g.emb_5,
    g.emb_6,
    g.emb_7,
    g.emb_8,
    g.emb_9,
    g.emb_10,
    g.emb_11,
    g.emb_12,
    g.emb_13,
    g.emb_14,
    g.emb_15,
    g.emb_16,
    g.emb_17,
    g.emb_18,
    g.emb_19,
    g.emb_20,
    g.emb_21,
    g.emb_22,
    g.emb_23,
    g.emb_24,
    g.emb_25,
    g.emb_26,
    g.emb_27,
    g.emb_28,
    g.emb_29,
    g.emb_30,
    g.emb_31,
    g.emb_32,
    g.emb_33,
    g.emb_34,
    g.emb_35,
    g.emb_36,
    g.emb_37,
    g.emb_38,
    g.emb_39,
    g.emb_40,
    g.emb_41,
    g.emb_42,
    g.emb_43,
    g.emb_44,
    g.emb_45,
    g.emb_46,
    g.emb_47,
    g.emb_48,
    g.emb_49,
    g.emb_50,
    g.emb_51,
    g.emb_52,
    g.emb_53,
    g.emb_54,
    g.emb_55,
    g.emb_56,
    g.emb_57,
    g.emb_58,
    g.emb_59,
    g.emb_60,
    g.emb_61,
    g.emb_62,
    g.emb_63,

    -- SPONSORS
    ns.n_sponsor_lead,
    ns.n_sponsor_collaborator,
    COALESCE(ns.n_sponsor_lead, 0) 
      + COALESCE(ns.n_sponsor_collaborator, 0) AS n_sponsors_total,

    -- Study Design
    d.allocation,
    d.primary_purpose,
    d.intervention_model,
    d.masking,
    d.is_blinded
FROM df_grafo g
LEFT JOIN gold.nodes_studies   s   ON s.study_id   = g.study_id
LEFT JOIN n_conditions         nc  ON nc.study_id  = g.study_id
LEFT JOIN n_countries          nctr ON nctr.study_id = g.study_id
LEFT JOIN n_interventions      ni  ON ni.study_id  = g.study_id
LEFT JOIN n_sponsors           ns  ON ns.study_id  = g.study_id
LEFT JOIN n_facilities         nf  ON nf.study_id  = g.study_id
LEFT JOIN design_features      d   ON d.study_id   = g.study_id;
select * from dataset_ml limit 20
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>study_id</th><th>brief_title</th><th>approved</th><th>degree_total</th><th>degree_norm</th><th>pagerank_norm</th><th>betweenness_norm</th><th>closeness_norm</th><th>community_louvain</th><th>n_conditions</th><th>n_countries</th><th>n_interventions</th><th>n_facilities</th><th>emb_0</th><th>emb_1</th><th>emb_2</th><th>emb_3</th><th>emb_4</th><th>emb_5</th><th>emb_6</th><th>emb_7</th><th>emb_8</th><th>emb_9</th><th>emb_10</th><th>emb_11</th><th>emb_12</th><th>emb_13</th><th>emb_14</th><th>emb_15</th><th>emb_16</th><th>emb_17</th><th>emb_18</th><th>emb_19</th><th>emb_20</th><th>emb_21</th><th>emb_22</th><th>emb_23</th><th>emb_24</th><th>emb_25</th><th>emb_26</th><th>emb_27</th><th>emb_28</th><th>emb_29</th><th>emb_30</th><th>emb_31</th><th>emb_32</